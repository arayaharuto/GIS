# %%
# import folium, a leaflet python library
import folium

# create a list of lat/lon pair for UCLA
reitaku = [35.8330, 139.9550]
parking1=[35.831641605594236, 139.956979550169]
parking2=[35.82726712417519, 139.9548052009304]
parking3=[35.829083923033835, 139.95755420726456]
parking4=[35.83771530576665, 139.9561931938043]
parking5=[35.83467767224591, 139.9561604425628]

# make the map
m = folium.Map(location=reitaku, zoom_start=15)

# add a marker
folium.Marker(parking1,popup="ナビパーク第一駐車場",tooltip="ナビパーク第一駐車場").add_to(m)
folium.Marker(parking2,popup="タイムズB柏光ヶ丘",tooltip="タイムズB柏光ヶ丘").add_to(m)
folium.Marker(parking3,popup="グリーンタウン光ヶ丘",tooltip="グリーンタウン光ヶ丘").add_to(m)
folium.Marker(parking4,popup="タイムズラポールB",tooltip="タイムズラポールB").add_to(m)
folium.Marker(parking5,popup="麗澤大学駐車場",tooltip="麗澤大学駐車場").add_to(m)



# show the map

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1b10a4fd2d7bdb1dc999c2f76c061d99 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1b10a4fd2d7bdb1dc999c2f76c061d99&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1b10a4fd2d7bdb1dc999c2f76c061d99 = L.map(
#                 &quot;map_1b10a4fd2d7bdb1dc999c2f76c061d99&quot;,
#                 {
#                     center: [35.833, 139.955],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f4a44cc4447f1dbe4acc76ee0438c56e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1b10a4fd2d7bdb1dc999c2f76c061d99);
#
#
#             var marker_b6a9dd8101ae5c65891fd39e298d840f = L.marker(
#                 [35.831641605594236, 139.956979550169],
#                 {}
#             ).addTo(map_1b10a4fd2d7bdb1dc999c2f76c061d99);
#
#
#         var popup_a9a89b8ae2323ba207af2f224b16e971 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c3ec4515ec1520db3ec726071679318f = $(`&lt;div id=&quot;html_c3ec4515ec1520db3ec726071679318f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ナビパーク第一駐車場&lt;/div&gt;`)[0];
#                 popup_a9a89b8ae2323ba207af2f224b16e971.setContent(html_c3ec4515ec1520db3ec726071679318f);
#
#
#
#         marker_b6a9dd8101ae5c65891fd39e298d840f.bindPopup(popup_a9a89b8ae2323ba207af2f224b16e971)
#         ;
#
#
#
#
#             marker_b6a9dd8101ae5c65891fd39e298d840f.bindTooltip(
#                 `&lt;div&gt;
#                      ナビパーク第一駐車場
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_176356ada156a32ec331cdc0082ef462 = L.marker(
#                 [35.82726712417519, 139.9548052009304],
#                 {}
#             ).addTo(map_1b10a4fd2d7bdb1dc999c2f76c061d99);
#
#
#         var popup_a287c8de21da6acfc1ea6e2d159a898c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_18889f0d4550e40232c8b2ed0e4232f2 = $(`&lt;div id=&quot;html_18889f0d4550e40232c8b2ed0e4232f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;タイムズB柏光ヶ丘&lt;/div&gt;`)[0];
#                 popup_a287c8de21da6acfc1ea6e2d159a898c.setContent(html_18889f0d4550e40232c8b2ed0e4232f2);
#
#
#
#         marker_176356ada156a32ec331cdc0082ef462.bindPopup(popup_a287c8de21da6acfc1ea6e2d159a898c)
#         ;
#
#
#
#
#             marker_176356ada156a32ec331cdc0082ef462.bindTooltip(
#                 `&lt;div&gt;
#                      タイムズB柏光ヶ丘
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_951e68548c6a90adab17146ba204ca8b = L.marker(
#                 [35.829083923033835, 139.95755420726456],
#                 {}
#             ).addTo(map_1b10a4fd2d7bdb1dc999c2f76c061d99);
#
#
#         var popup_87217d0a74eafe95cd048f600d598352 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7f6a625d04adfe3d40dc64bfb0fa377f = $(`&lt;div id=&quot;html_7f6a625d04adfe3d40dc64bfb0fa377f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;グリーンタウン光ヶ丘&lt;/div&gt;`)[0];
#                 popup_87217d0a74eafe95cd048f600d598352.setContent(html_7f6a625d04adfe3d40dc64bfb0fa377f);
#
#
#
#         marker_951e68548c6a90adab17146ba204ca8b.bindPopup(popup_87217d0a74eafe95cd048f600d598352)
#         ;
#
#
#
#
#             marker_951e68548c6a90adab17146ba204ca8b.bindTooltip(
#                 `&lt;div&gt;
#                      グリーンタウン光ヶ丘
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a8467465100b9d8bcaa1dcb323c4a12a = L.marker(
#                 [35.83771530576665, 139.9561931938043],
#                 {}
#             ).addTo(map_1b10a4fd2d7bdb1dc999c2f76c061d99);
#
#
#         var popup_8aadfa6d74f43a6fdaecd390436baef3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c6c1a88553afa765d5303410da0d53dd = $(`&lt;div id=&quot;html_c6c1a88553afa765d5303410da0d53dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;タイムズラポールB&lt;/div&gt;`)[0];
#                 popup_8aadfa6d74f43a6fdaecd390436baef3.setContent(html_c6c1a88553afa765d5303410da0d53dd);
#
#
#
#         marker_a8467465100b9d8bcaa1dcb323c4a12a.bindPopup(popup_8aadfa6d74f43a6fdaecd390436baef3)
#         ;
#
#
#
#
#             marker_a8467465100b9d8bcaa1dcb323c4a12a.bindTooltip(
#                 `&lt;div&gt;
#                      タイムズラポールB
#                  &lt;/div&gt;`,
#                 {&quot;
