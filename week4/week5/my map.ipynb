# %% [markdown]
# my　map
#
#
# 麗澤大学周辺の駐車場

# %%
# import folium, a leaflet python library
import folium

# create a list of lat/lon pair for UCLA
reitaku = [35.8330, 139.9550]
parking1=[35.831641605594236, 139.956979550169]
parking2=[35.82726712417519, 139.9548052009304]
parking3=[35.829083923033835, 139.95755420726456]
parking4=[35.83771530576665, 139.9561931938043]
parking5=[35.83467767224591, 139.9561604425628]

# make the map
m = folium.Map(location=reitaku, zoom_start=15)

# add a marker
folium.Marker(parking1,popup="ナビパーク第一駐車場",tooltip="ナビパーク第一駐車場").add_to(m)
folium.Marker(parking2,popup="タイムズB柏光ヶ丘",tooltip="タイムズB柏光ヶ丘").add_to(m)
folium.Marker(parking3,popup="グリーンタウン光ヶ丘",tooltip="グリーンタウン光ヶ丘").add_to(m)
folium.Marker(parking4,popup="タイムズラポールB",tooltip="タイムズラポールB").add_to(m)
folium.Marker(parking5,popup="麗澤大学駐車場",tooltip="麗澤大学駐車場").add_to(m)



# show the map

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
